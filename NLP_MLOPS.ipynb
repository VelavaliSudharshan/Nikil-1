# %% [markdown]
# <a href="https://colab.research.google.com/github/VelavaliSudharshan/Nikil-1/blob/main/NLP_MLOPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-play-scraper

# %% [markdown]
# rey code simple eay try to understand
# # New section

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app, Sort, reviews_all

# %%
from google_play_scraper import Sort, reviews_all

result_FYER = reviews_all(
    'com.fyers.trader',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='IN', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with=5 # defaults to None(means all score)
)

# %%
result_UPSTOX =reviews_all(
    'in.upstox.app',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='IN', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with=5 # defaults to None(means all score)
)

# %%
result =result_FYER +result_UPSTOX

# %%
result
# Out:
# [{'reviewId': '6659e6c3-858b-4bba-b50e-b1479fabe14b',
#   'userName': 'Mayank Singh',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW_3_AFd2q9Ctl4n441Vqq0ZBCIpe5XAx9TXFJptkf8Kg',
#   'content': "Updated - After uninstalling and installing again, it worked. I would have given 5⭐ but the issue with the chart is what made me give it 3. Earlier whatever settings I applied to the chart was synced properly and everytime I open the chart whether on app or desktop the settings was as it is, but since last few days its behaviour is unusual as everytime I open the chart all the settings and customisations are lost and I have to do it again and again, and it's really really frustrating 😔",
#   'score': 5,
#   'thumbsUpCount': 34,
#   'reviewCreatedVersion': '2.0.12',
#   'at': datetime.datetime(2024, 2, 14, 10, 14, 54),
#   'replyContent': 'Hi Mayank, please raise a ticket at support@fyers.in from your registered E-mail ID so our team can check and assist you accordingly.',
# ...

# %%
pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=94e2d72832e1e5d2526309a7828c266263022c2a719aa453a82b93246991806e
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

# %%
spark = SparkSession.builder.master("local[*]").appName("AppendDataToDataFrame").getOrCreate()

# Define the schema for the DataFrame
schema = StructType([
    StructField("reviewId", StringType(), True),
    StructField("userName", StringType(), True),
    StructField("userImage", StringType(), True),
    StructField("content", StringType(), True),
    StructField("score", IntegerType(), True)
])

# %%
ps

# %%
new_df = spark.createDataFrame(result, schema=schema)

# %%
new_df.show(truncate=False)
# Out:
# +------------------------------------+-------------------------+--------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# ...

# %%
comment=new_df.select("content","reviewId")

# %%
comment.printSchema()
# Out:
# root
#  |-- content: string (nullable = true)
#  |-- reviewId: string (nullable = true)

# %%
spark.stop()
